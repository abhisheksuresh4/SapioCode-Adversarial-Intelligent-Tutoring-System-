# %%
from bkt.model import bkt_update
print(bkt_update(0.2, correct=False))
print(bkt_update(0.2, correct=True))
print(bkt_update(0.8, correct=False))
print(bkt_update(0.8, correct=True))
# Out:
# 0.1272727272727273
# 0.5764705882352941
# 0.4000000000000001
# 0.9526315789473684
